# %% [markdown]
# <a href="https://colab.research.google.com/github/heightsInnov/bu-bootcamp/blob/main/week-01/homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DX 602: Homework 01
#
# **Subject matter:**
#
# variables, literals, numbers, arithmetic, strings, lists
#
#
# **Instructions:**
#
# Be sure to run each code block after you edit it to make sure it runs as expected. When you are done, we strongly recommend you run all the code from scratch (Runtime menu -> Restart and Run all) to make sure your current code works for all problems.
#
# If your code raises an exception when run from scratch, it will interfere with the auto-grader process causing you to lose some or all points for this homework. Please ask for help on Piazza, attend office hours or schedule an appointment with your learning facilitator if you get stuck.
#
#
# **Warning about AI:**
#
# While we encourage you to use AI to generate practice problems, we strongly recommend against using it to solve this assignment. The goal of this assignment is for you to learn these concepts, and while using AI may help you solve these problems quicker, you will not be learning anything and will get confused as this module progresses. So, try to solve these problems with the help of the sample problems and examples on blackboard.
#
#
# **Solution:**
#
# For each problem description, a sample output has been included to show what the expected output should look like.

# %% [markdown]
# **Problem 1**
#
# **Concept:** *Variables and assignment statements.*
#
# **Task:**
#
# * Create a variable called `my_int` and assign your favorite integer value to it
#
# * Create a variable called `my_float` and assign your favorite floating point number to it
#
# * Create a variable called `my_str` and assign your favorite string literal to it
#
# * Print each variable using a descriptive message
#
# **Sample Output:**
#
# ```
# my favorite integer is 78
# my favorite float is 20.65
# my favorite string is dog
# ```

# %%
# TO DO: WRITE YOUR CODE/SOLUTION BELOW
my_int = 7
my_float = 7.7
my_str = 'Ayotola'

print('my favorite integer is', my_int)
print('my favorite float is' , my_float)
print('my favorite string is', my_str)
# Out:
# my favorite integer is 7
# my favorite float is 7.7
# my favorite string is Ayotola

# %% [markdown]
# **Problem 2**
#
# **Concept:** *Performing arithmetic operations with integers.*
#
# **Task:**
#
# * Create a variable `x` that stores the result of adding two integers
# * Create a variable `y` that multiplies `x` by another integer
# * Print both variables, one per line
#
# **Sample Output:**
#
# ```
# x = 27
# y = 40
# ```

# %%
# TO DO: WRITE YOUR CODE/SOLUTION BELOW

x =  5 + 7
y = x * 5
print('x =',x)
print('y =',y)
# Out:
# x = 12
# y = 60

# %% [markdown]
# **Problem 3**
#
# **Concept:** *Multiplication and division with floating-point numbers.*
#
# **Task:**
#
# Using the given width and height, calculate:
#
# * The area and assign it to a variable `area`
#
# * The ratio of width to height and assign it to a variable `ratio`
#
# * Print both variables
#
# **Sample Output:**
#
# ```
# area = 12
# ratio = 4.25
# ```

# %%
# starter code:
width = 2.5
height = 5.2

# TO DO: WRITE YOUR CODE/SOLUTION BELOW
area = width * height
ratio = width / height

print('area = ',area)
print('ratio = ', ratio)
# Out:
# area =  13.0
# ratio =  0.4807692307692307

# %% [markdown]
# **Problem 4**
#
# **Concept:** *Division that results a floating-point number.*
#
# **Task:**
#
# * Given the number of cookies and players, calculate how many cookies each player receives if cookies are divided evenly
# * Assign the result to a variable ```cookies_per_player```
# * Print the result
#
# **Sample Output:**
#
# ```Each player gets 4.7 cookies.```

# %%
# starter code:
cookies = 48
players = 13

# TO DO: WRITE YOUR CODE/SOLUTION BELOW
# to do: calculate number of cookies for each player on hockey team

cookies_per_player = cookies / players
print('Each player gets ', cookies_per_player, 'cookies')
# Out:
# Each player gets  3.6923076923076925 cookies

# %% [markdown]
# **Problem 5**
#
# **Concept:** *Arithmetic with integer division and remainder.*
#
# **Task:**
#
# Using integer division and remainder, calculate:
#
# * How many whole cookies each player receives and assign it to a variable ```whole_cookies_per_player```
#
# * How many cookies are left over and assign it to a variable ```cookies_left_over```
#
# * Print both results
#
# **Sample Output:**
#
# ```
# Each player gets 5 cookies.
# That leaves 10 cookies for the coach!
# ```

# %%
# starter code:
cookies = 48
players = 13

# TO DO: WRITE YOUR CODE/SOLUTION BELOW
# to do: calculate number of cookies for each player on hockey team
whole_cookies_per_player = cookies // players
print('Each player gets', whole_cookies_per_player, 'cookies')

cookies_left_over = cookies % players
print('That leaves', cookies_left_over, 'for the coach')
# Out:
# Each player gets 3 cookies
# That leaves 9 for the coach

# %% [markdown]
# **Problem 6**
#
# **Concept:** *String indexing. Accessing individual characters in a string.*
#
# **Task:**
#
# * Given a first name and last name, extract the first character of each and combine them to form a string variable called ```initials```
# * Print the result
#
# **Sample Output:**
#
# ```Initials are: km```

# %%
# starter code:
first_name = 'john'
last_name = 'lennon'

# TO DO: WRITE YOUR CODE/SOLUTION BELOW
initials = first_name[0] + last_name[0]
print('Initials are:', initials)
# Out:
# Initials are: jl

# %% [markdown]
# **Problem 7**
#
# **Concept:** *Extracting substrings using string slicing.*
#
# **Task:**
#
# Split the string color into two parts:
#
# * First half called ```first_half```
#
# * Second half called ```last_half```
#
# * Print both substrings
#
# **Sample Output:**
#
# ```
# first half: light
# last half: blue
# ```

# %%
# starter code:
color = 'darkblue'

# TO DO: WRITE YOUR CODE/SOLUTION BELOW
first_half = color[0:4]
print('first half:', first_half)

last_half = color[-4:]
print('last half:', last_half)
# Out:
# first half: dark
# last half: blue

# %% [markdown]
# **Problem 8**
#
# **Concept:** *Extracting elements by position*
#
# **Task:**
#
# Given a standard gmail email, extract the username as ```user``` from the email
#
# **Sample Output:**
#
# ```The username is johndoe```

# %%
# starter code:
email = 'jane@gmail.com'

# TO DO: WRITE YOUR CODE/SOLUTION BELOW
user = email[:4]
print('The username is', user)
# Out:
# The username is jane

# %% [markdown]
# **Problem 9**
#
# **Concept:** *Creating lists using literal values.*
#
# **Task:**
#
# Create a list called ```my_list``` containing your favorite three integers and print it.
#
# **Sample Output:**
#
# ```my_list = [5, 3, 4]```

# %%
from IPython.core.display import mimetypes
# TO DO: WRITE YOUR CODE/SOLUTION BELOW
my_list = [8, 3, 2]
print('my_list = ',my_list)
# Out:
# my_list =  [8, 3, 2]

# %% [markdown]
# **Problem 10**
#
# **Concept:** *Creating lists using existing variables.*
#
# **Task:**
#
# Using the provided variables, create a list called ```ordered_list``` in a specific order - first variable, third variable, second variable, and then print it.
#
# **Sample Output:**
#
# ```ordered_list = [5, 1, 4]```

# %%
# starter code:
a = 6
b = 7
c = 1

# TO DO: WRITE YOUR CODE/SOLUTION BELOW
ordered_list = [a, c, b]

print('ordered_list =', ordered_list)
# Out:
# ordered_list = [6, 1, 7]

# %% [markdown]
# **Problem 11**
#
# **Concept:** *Using built-in functions on lists.*
#
#  `len` and `sum`
#
#  **Task:**
#
#  For the given list, calculate:
#
# * Number of elements and assign it to a variable `length`
#
# * Sum of the elements and assign it to a variable `total`
#
# * Mean (average) and assign it to a variable `mean`
#
# * Print all results in one sentence
#
# **Sample Output:**
#
# ```The list contains 9 elements, the sum is 40 and the mean is 3.7```

# %%
from IPython.core.magics.execution import math
# starter code:
values = [6,1,7,3,5,8,2,3,6,1]

# TO DO: WRITE YOUR CODE/SOLUTION BELOW
length = len(values)
total = sum(values)
mean = total/length

print('The list contains', length, 'elements, the sum is', total,'and the mean is', mean)
# Out:
# The list contains 10 elements, the sum is 42 and the mean is 4.2

# %% [markdown]
# **Problem 12**
#
# **Concept:** *Assessing elements by position*
#
# **Task:**
#
# From the given list, extract:
#
# * First element and assign it to a variable `first`
#
# * Middle element and assign it to a variable `middle`
#
# * Last element and assign it to a variable `last`
#
# * Print each value on its own line
#
# **Sample Output:**
#
# ```
# The first value is 7
# The middle value is 3
# The last value is 9
# ```

# %%
# starter code:
values = [6,1,7,3,5,8,2,3,6,1]

# TO DO: WRITE YOUR CODE/SOLUTION BELOW
first = values[0]
middle = values[(len(values)//2)]
last = values[-1]

print('The first value is', first)
print('The middle value is', middle)
print('The last value is', last)
# Out:
# The first value is 6
# The middle value is 8
# The last value is 1

# %% [markdown]
# **Problem 13**
#
# **Concept:** *Extracting sublists using slicing*
#
# **Task:**
#
# From the list:
#
# * Extract first three elements and assign it to a variable `first_three`
#
# * Extract last three elements and assign it to a variable `last_three`
#
# * Combine them into a new list and assign it to a variable `combined`
#
# * Compute the mean of the combined list and assign it to a variable `mean_combined`
#
# * Print the combined list and the mean
#
# **Notes:**
#
# * You may use the built-in functions `len` and `sum`; you may not
# use any loops or library functions.
#
# **Sample Output:**
#
# ```
# The first 3 elements and last 3 elements combined are : [1, 4, 5, 3, 6, 7]
# And the mean of the combined list is 5.0
# ```

# %%
# starter code:
values = [6,1,7,3,5,8,2,3,6,1]

# TO DO: WRITE YOUR CODE/SOLUTION BELOW
first_three = values[0:3]
last_three = values[-3:]
combined = first_three + last_three
mean_combined = sum(combined)/len(combined)

print('The first 3 elements and last 3 elements combined are :', combined)
print('And the mean of the combined list is', mean_combined)
# Out:
# The first 3 elements and last 3 elements combined are : [6, 1, 7, 3, 6, 1]
# And the mean of the combined list is 4.0
